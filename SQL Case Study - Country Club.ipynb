# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """

SELECT s1.memid, s1.surname || ',' || s1.firstname as member, 
s1.recommendedby, s2.surname || ',' || s2.firstname as recommender, 
s2.memid
FROM Members as s1
LEFT JOIN Members as s2
ON s1.recommendedby = s2.memid
WHERE s1.memid != 'None'
ORDER BY member;

        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (15, 'Bader,Florence', '9', 'Stibbons,Ponder', 9)
# (12, 'Baker,Anne', '9', 'Stibbons,Ponder', 9)
# (16, 'Baker,Timothy', '13', 'Farrell,Jemima', 13)
# (8, 'Boothe,Tim', '3', 'Rownam,Tim', 3)
# (5, 'Butters,Gerald', '1', 'Smith,Darren', 1)
# (22, 'Coplin,Joan', '16', 'Baker,Timothy', 16)
# (36, 'Crumpet,Erica', '2', 'Smith,Tracy', 2)
# (7, 'Dare,Nancy', '4', 'Joplette,Janice', 4)
# (28, 'Farrell,David', '', None, None)
# (13, 'Farrell,Jemima', '', None, None)
# (0, 'GUEST,GUEST', '', None, None)
# (20, 'Genting,Matthew', '5', 'Butters,Gerald', 5)
# (35, 'Hunt,John', '30', 'Purview,Millicent', 30)
# (11, 'Jones,David', '4', 'Joplette,Janice', 4)
# (26, 'Jones,Douglas', '11', 'Jones,David', 11)
# (4, 'Joplette,Janice', '1', 'Smith,Darren', 1)
# (21, 'Mackenzie,Anna', '1', 'Smith,Darren', 1)
# (10, 'Owen,Charles', '1', 'Smith,Darren', 1)
# (17, 'Pinker,David', '13', 'Farrell,Jemima', 13)
# (30, 'Purview,Millicent', '2', 'Smith,Tracy', 2)
# (3, 'Rownam,Tim', '', None, None)
# (27, 'Rumney,Henrietta', '20', 'Genting,Matthew', 20)
# (24, 'Sarwin,Ramnaresh', '15', 'Bader,Florence', 15)
# (1, 'Smith,Darren', '', None, None)
# (37, 'Smith,Darren', '', None, None)
# (14, 'Smith,Jack', '1', 'Smith,Darren', 1)
# (2, 'Smith,Tracy', '', None, None)
# (9, 'Stibbons,Ponder', '6', 'Tracy,Burton', 6)
# (6, 'Tracy,Burton', '', None, None)
# (33, 'Tupperware,Hyacinth', '', None, None)
# (29, 'Worthington-Smyth,Henry', '2', 'Smith,Tracy', 2)
